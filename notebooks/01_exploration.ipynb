# %%
import pandas as pd

df = pd.read_csv("../data/PPLC_Issued_Building_Permits_5423838102305819771.csv")

df["Active_Parcel"].value_counts()
# Out:
# Active_Parcel
# Y    17728
# N      363
# Name: count, dtype: int64

# %%
df["Estimated_Project_Value"].describe()
# Out:
# count    1.799300e+04
# mean     1.448575e+06
# std      8.923243e+06
# min      1.000000e+00
# 25%      4.050000e+04
# 50%      1.920000e+05
# 75%      4.500000e+05
# max      7.750000e+08
# Name: Estimated_Project_Value, dtype: float64

# %%
df["Estimated_Project_Value"].hist(bins=50)
# Out:
# <Axes: >

# %%
df[df["Estimated_Project_Value"] < 100][["Work_Type", "Primary_Work_Scope", "Permit_Name", "Permit_Status"]]
# Out:
#           Work_Type Primary_Work_Scope  \
# 797      Renovation         Renovation
# 984      Renovation         Renovation
# 1223     Renovation         Renovation
# 2187     Renovation         Renovation
# 3231     Renovation         Renovation
# 3450     Renovation         Renovation
# 3637     Renovation         Renovation
# 4387     Renovation         Renovation
# 4477   New Building       New Building
# 5062     Renovation         Renovation
# 6986     Renovation         Renovation
# 7861   New Building       New Building
# 8790     Renovation         Renovation
# 9895     Renovation         Renovation
# 10580  New Building       New Building
# 11547  New Building       New Building
# 11828  New Building       New Building
# 11838    Renovation         Renovation
# 12781      Addition           Addition
# 12866  New Building       New Building
# 13546    Renovation         Renovation
# 13603  New Building       New Building
# 13667  New Building       New Building
# ...
